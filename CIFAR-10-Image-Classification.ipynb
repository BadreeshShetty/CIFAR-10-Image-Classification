# %% [markdown]
# # Cifar-10 Image Classification Dataset
#
# Source - https://www.cs.toronto.edu/~kriz/cifar.html
# ---
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.
# The labels are as follow :
# 1. airplane
# 2. automobile
# 3. bird
# 4. cat
# 5. deer
# 6. dog
# 7. frog
# 8. horse
# 9. ship
# 10. truck
#
# **Objective**: To classify the given image into one of the 10 given labels.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten,BatchNormalization
from keras.optimizers import Adam
from keras.regularizers import l2
# Out:
# D:\Anaconda3\lib\site-packages\h5py\__init__.py:72: UserWarning: h5py is running against HDF5 1.10.2 when it was built against 1.10.3, this may cause problems
#   '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print('y_train shape:', y_train.shape)
print('x_test shape:', x_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# y_train shape: (50000, 1)
# x_test shape: (10000, 32, 32, 3)
# y_test shape: (10000, 1)

# %%
labels = {0: "airplane",
          1: "automobile",
          2: "bird",
          3: "cat",
          4: "deer",
          5: "dog",
          6: "frog",
          7: "horse",
          8: "ship",
          9: "truck"}

# %%
img_nums = 10
plt.figure(figsize=(10,3))
for i in range(0, img_nums):
  ax = plt.subplot(1, 10, i+1)
  plt.imshow(x_test[i])
  ax.set_title(str(labels[y_test[i][0]]))
  ax.axis("off")
plt.show()

# %%
num_classes = 10
y_train_one_hot = keras.utils.to_categorical(y_train, num_classes)
y_test_one_hot = keras.utils.to_categorical(y_test, num_classes)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255.
x_test /= 255.

# %% [markdown]
# ## ConvNet

# %%
def convnet():
  model = Sequential([
  Conv2D(32, (3, 3), padding="same",activation="relu",kernel_regularizer=l2(0.01), input_shape=x_train.shape[1:]),
  Conv2D(32, (3, 3),kernel_regularizer=l2(0.01), activation="relu"),
  BatchNormalization(),
  MaxPooling2D(pool_size=(2, 2)),
  Dropout(0.25),
  Conv2D(64, (3, 3), padding="same", activation="relu",kernel_regularizer=l2(0.01)),
  Conv2D(64, (3, 3), activation="relu",kernel_regularizer=l2(0.01)),
  BatchNormalization(),
  MaxPooling2D(pool_size=(2, 2)),
  Dropout(0.25),
  Conv2D(128, (3, 3), padding="same", activation="relu",kernel_regularizer=l2(0.01)),
  Conv2D(128, (3, 3), activation="relu",kernel_regularizer=l2(0.01)),
  Flatten(),
  Dense(1024, activation="relu"),
  Dropout(0.5),
  Dense(512, activation="relu"),
  Dropout(0.5),
  Dense(num_classes, activation="softmax"),
  ])
  return model

# %%
model = convnet()
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 13, 13, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 6, 6, 128)         73856
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 128)         147584
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 2,915,498
# Trainable params: 2,915,306
# Non-trainable params: 192
# _________________________________________________________________

# %%
epochs = 50
batch_size = 256
adam = Adam(lr=0.0001)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train_one_hot, batch_size=batch_size, epochs=epochs,
                  validation_data=(x_test, y_test_one_hot),
                  shuffle=True, verbose=1)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 11s 215us/step - loss: 5.2950 - acc: 0.2542 - val_loss: 4.6504 - val_acc: 0.3932
# Epoch 2/50
# 50000/50000 [==============================] - 8s 168us/step - loss: 4.3238 - acc: 0.4058 - val_loss: 3.9868 - val_acc: 0.4527
# Epoch 3/50
# 50000/50000 [==============================] - 8s 168us/step - loss: 3.7050 - acc: 0.4694 - val_loss: 3.4536 - val_acc: 0.4987
# Epoch 4/50
# 50000/50000 [==============================] - 8s 168us/step - loss: 3.2452 - acc: 0.5190 - val_loss: 3.0484 - val_acc: 0.5362
# Epoch 5/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 2.8778 - acc: 0.5587 - val_loss: 2.7212 - val_acc: 0.5660
# Epoch 6/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 2.5813 - acc: 0.5947 - val_loss: 2.4440 - val_acc: 0.6087
# Epoch 7/50
# 50000/50000 [==============================] - 8s 168us/step - loss: 2.3394 - acc: 0.6233 - val_loss: 2.1914 - val_acc: 0.6474
# Epoch 8/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 2.1479 - acc: 0.6459 - val_loss: 2.0283 - val_acc: 0.6673
# Epoch 9/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 1.9852 - acc: 0.6668 - val_loss: 1.9743 - val_acc: 0.6580
# Epoch 10/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 1.8413 - acc: 0.6855 - val_loss: 1.7967 - val_acc: 0.6928
# Epoch 11/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 1.7197 - acc: 0.7042 - val_loss: 1.7521 - val_acc: 0.6786
# Epoch 12/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 1.6180 - acc: 0.7181 - val_loss: 1.7132 - val_acc: 0.6888
# Epoch 13/50
# 50000/50000 [==============================] - 8s 168us/step - loss: 1.5281 - acc: 0.7322 - val_loss: 1.6420 - val_acc: 0.6933
# Epoch 14/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 1.4498 - acc: 0.7439 - val_loss: 1.4204 - val_acc: 0.7453
# Epoch 15/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 1.3788 - acc: 0.7538 - val_loss: 1.4206 - val_acc: 0.7381
# Epoch 16/50
# 50000/50000 [==============================] - 8s 168us/step - loss: 1.3125 - acc: 0.7659 - val_loss: 1.3329 - val_acc: 0.7504
# Epoch 17/50
# 50000/50000 [==============================] - 8s 168us/step - loss: 1.2582 - acc: 0.7735 - val_loss: 1.2594 - val_acc: 0.7692
# Epoch 18/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 1.2045 - acc: 0.7814 - val_loss: 1.2327 - val_acc: 0.7702
# Epoch 19/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 1.1580 - acc: 0.7893 - val_loss: 1.1880 - val_acc: 0.7795
# Epoch 20/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 1.1132 - acc: 0.7980 - val_loss: 1.1570 - val_acc: 0.7822
# Epoch 21/50
# 50000/50000 [==============================] - 8s 168us/step - loss: 1.0741 - acc: 0.8024 - val_loss: 1.1140 - val_acc: 0.7903
# Epoch 22/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 1.0369 - acc: 0.8105 - val_loss: 1.1000 - val_acc: 0.7879
# Epoch 23/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 1.0056 - acc: 0.8158 - val_loss: 1.1112 - val_acc: 0.7776
# Epoch 24/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 0.9741 - acc: 0.8217 - val_loss: 1.0811 - val_acc: 0.7872
# Epoch 25/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 0.9393 - acc: 0.8293 - val_loss: 1.3169 - val_acc: 0.7266
# Epoch 26/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 0.9136 - acc: 0.8329 - val_loss: 1.0373 - val_acc: 0.7944
# Epoch 27/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 0.8887 - acc: 0.8380 - val_loss: 1.0797 - val_acc: 0.7780
# Epoch 28/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 0.8611 - acc: 0.8430 - val_loss: 0.9869 - val_acc: 0.8071
# Epoch 29/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 0.8367 - acc: 0.8487 - val_loss: 1.0004 - val_acc: 0.8030
# Epoch 30/50
# 50000/50000 [==============================] - 8s 168us/step - loss: 0.8138 - acc: 0.8556 - val_loss: 0.9630 - val_acc: 0.8107
# Epoch 31/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 0.7937 - acc: 0.8589 - val_loss: 1.0342 - val_acc: 0.7843
# Epoch 32/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 0.7787 - acc: 0.8610 - val_loss: 1.0511 - val_acc: 0.7814
# Epoch 33/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 0.7580 - acc: 0.8657 - val_loss: 0.9095 - val_acc: 0.8154
# Epoch 34/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 0.7401 - acc: 0.8678 - val_loss: 0.9193 - val_acc: 0.8140
# Epoch 35/50
# 50000/50000 [==============================] - 8s 168us/step - loss: 0.7288 - acc: 0.8716 - val_loss: 0.9667 - val_acc: 0.8028
# Epoch 36/50
# 50000/50000 [==============================] - 8s 170us/step - loss: 0.7000 - acc: 0.8799 - val_loss: 0.8966 - val_acc: 0.8214
# Epoch 37/50
# 50000/50000 [==============================] - 9s 179us/step - loss: 0.6882 - acc: 0.8812 - val_loss: 0.9031 - val_acc: 0.8171
# Epoch 38/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 0.6701 - acc: 0.8871 - val_loss: 0.9298 - val_acc: 0.8069
# Epoch 39/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 0.6548 - acc: 0.8896 - val_loss: 0.8958 - val_acc: 0.8208
# Epoch 40/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 0.6438 - acc: 0.8902 - val_loss: 0.8970 - val_acc: 0.8218
# Epoch 41/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 0.6313 - acc: 0.8933 - val_loss: 0.8791 - val_acc: 0.8238
# Epoch 42/50
# 50000/50000 [==============================] - 9s 170us/step - loss: 0.6179 - acc: 0.8980 - val_loss: 0.8765 - val_acc: 0.8242
# Epoch 43/50
# 50000/50000 [==============================] - 9s 190us/step - loss: 0.5993 - acc: 0.9020 - val_loss: 0.9223 - val_acc: 0.8096
# Epoch 44/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 0.5943 - acc: 0.9056 - val_loss: 0.8414 - val_acc: 0.8297
# Epoch 45/50
# 50000/50000 [==============================] - 8s 169us/step - loss: 0.5796 - acc: 0.9069 - val_loss: 0.8964 - val_acc: 0.8169
# Epoch 46/50
# 50000/50000 [==============================] - 9s 171us/step - loss: 0.5669 - acc: 0.9108 - val_loss: 0.8890 - val_acc: 0.8157
# Epoch 47/50
# 50000/50000 [==============================] - 9s 180us/step - loss: 0.5558 - acc: 0.9131 - val_loss: 0.8760 - val_acc: 0.8200
# Epoch 48/50
# 50000/50000 [==============================] - 9s 171us/step - loss: 0.5431 - acc: 0.9172 - val_loss: 0.8619 - val_acc: 0.8253
# Epoch 49/50
# 50000/50000 [==============================] - 9s 175us/step - loss: 0.5386 - acc: 0.9171 - val_loss: 0.8726 - val_acc: 0.8248
# Epoch 50/50
# 50000/50000 [==============================] - 9s 171us/step - loss: 0.5270 - acc: 0.9206 - val_loss: 0.8565 - val_acc: 0.8283

# %%
scores = model.evaluate(x_test, y_test_one_hot, batch_size=256, verbose=1)
print('\nTest result: %.3f loss: %.3f' %(scores[1]*100,scores[0]))
# Out:
# 10000/10000 [==============================] - 1s 59us/step
#
# Test result: 82.830 loss: 0.857

# %%
model.save('cifar-10-model.h5')

# %%
y_pred = model.predict(x_test)

# %%
y_pred_label = np.argmax(y_pred, axis=1)

# %% [markdown]
# ## Confusion Matrix

# %%
import itertools
from sklearn.metrics import confusion_matrix
cnf_matrix = confusion_matrix(y_test, y_pred_label)
cm = cnf_matrix.astype('float32')/cnf_matrix.sum(axis=1)
plt.figure(figsize=(10, 10))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Greys)
tick_marks = np.arange(10)
plt.xticks(tick_marks, [labels[i] for i in range(10)])
plt.yticks(tick_marks, [labels[i] for i in range(10)])
fmt = '.2f'
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], fmt),
             horizontalalignment="center",
             color="white" if cm[i, j] > thresh else "black")
plt.colorbar()
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.grid(False)
plt.show()

# %%
# Loss Curves
plt.figure(figsize=[10,8])
plt.plot(history.history['loss'],'r',linewidth=3.0)
plt.plot(history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
 
# Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['acc'],'r',linewidth=3.0)
plt.plot(history.history['val_acc'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16);

# %% [markdown]
# ## Prediction

# %%
num_imgs = 15
plt.figure(figsize=(15,1))
for i in range(0, num_imgs):
  ax = plt.subplot(1, 15, i+1)
  plt.imshow(x_test[i])
  ax.set_title(str(labels[y_pred_label[i]]))
  ax.axis("off")
plt.show()
